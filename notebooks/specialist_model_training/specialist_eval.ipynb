# %% [markdown]
# # Evaluating our finetuned specialist model:
# ## Predicting Product Prices

# %%
# pip installs

# !pip install -q --upgrade torch==2.5.1+cu124 torchvision==0.20.1+cu124 torchaudio==2.5.1+cu124 --index-url https://download.pytorch.org/whl/cu124
# !pip install -q --upgrade requests==2.32.3 bitsandbytes==0.46.0 transformers==4.48.3 accelerate==1.3.0 datasets==3.2.0 peft==0.14.0 trl==0.14.0 matplotlib wandb
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.2/908.2 MB 1.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 44.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 46.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 67.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 42.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 82.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 904.4 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 8.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 82.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.6/209.6 MB 1.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 118.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 11.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 81.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 336.6/336.6 kB 20.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 28.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.8/374.8 kB 22.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.9/313.9 kB 19.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 77.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 15.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 80.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.3 which is incompatible.
# google-adk 1.19.0 requires requests<3.0.0,>=2.32.4, but you have requests 2.32.3 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2024.9.0 which is incompatible.

# %%
# imports

import os
import re
import math
from tqdm import tqdm
from google.colab import userdata
from huggingface_hub import login
import torch
import torch.nn.functional as F
import transformers
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, set_seed
from datasets import load_dataset, Dataset, DatasetDict
from datetime import datetime
from peft import PeftModel
import matplotlib.pyplot as plt

# %%
# Constants

BASE_MODEL = "meta-llama/Meta-Llama-3.1-8B"
PROJECT_NAME = "pricer"
HF_USER = "laureen-ai"

# The run itself

RUN_NAME = "2025-11-28_14.25.57"
PROJECT_RUN_NAME = f"{PROJECT_NAME}-{RUN_NAME}"
REVISION = None # "e8d637df551603dc86cd7a1598a8f44af4d7ae36"
FINETUNED_MODEL = f"{HF_USER}/{PROJECT_RUN_NAME}"

# Data

DATASET_NAME = f"{HF_USER}/pricer-data"

# Hyperparameters for QLoRA

QUANT_4_BIT = True

# %matplotlib inline

# Used for writing to output in color

GREEN = "\033[92m"
YELLOW = "\033[93m"
RED = "\033[91m"
RESET = "\033[0m"
COLOR_MAP = {"red":RED, "orange": YELLOW, "green": GREEN}

# %% [markdown]
# ### Log in to HuggingFace

# %%
# Log in to HuggingFace

hf_token = userdata.get('HF_TOKEN')
login(hf_token, add_to_git_credential=True)

# %%
dataset = load_dataset(DATASET_NAME)
train = dataset['train']
test = dataset['test']
# Out:
# README.md:   0%|          | 0.00/416 [00:00<?, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/184M [00:00<?, ?B/s]
# data/test-00000-of-00001.parquet:   0%|          | 0.00/909k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/400000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2000 [00:00<?, ? examples/s]

# %%
test[0]
# Out:
# {'text': "How much does this cost to the nearest dollar?\n\nOEM AC Compressor w/A/C Repair Kit For Ford F150 F-150 V8 & Lincoln Mark LT 2007 2008 - BuyAutoParts NEW\nAs one of the world's largest automotive parts suppliers, our parts are trusted every day by mechanics and vehicle owners worldwide. This A/C Compressor and Components Kit is manufactured and tested to the strictest OE standards for unparalleled performance. Built for trouble-free ownership and 100% visually inspected and quality tested, this A/C Compressor and Components Kit is backed by our 100% satisfaction guarantee. Guaranteed Exact Fit for easy installation 100% BRAND NEW, premium ISO/TS 16949 quality - tested to meet or exceed OEM specifications Engineered for superior durability, backed by industry-leading unlimited-mileage warranty Included in this K\n\nPrice is $",
#  'price': 374.41}

# %% [markdown]
# ## Now load the Tokenizer and Model

# %%
# pick the right quantization (bug with the 8 bit version!)

if QUANT_4_BIT:
  quant_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=torch.bfloat16,
    bnb_4bit_quant_type="nf4"
  )
else:
  quant_config = BitsAndBytesConfig(
    load_in_8bit=True,
    bnb_8bit_compute_dtype=torch.bfloat16
  )

# %%
# Load the Tokenizer and the Model

tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

base_model = AutoModelForCausalLM.from_pretrained(
    BASE_MODEL,
    quantization_config=quant_config,
    device_map="auto",
)
base_model.generation_config.pad_token_id = tokenizer.pad_token_id

# Load the fine-tuned model with PEFT
if REVISION:
  fine_tuned_model = PeftModel.from_pretrained(base_model, FINETUNED_MODEL, revision=REVISION)
else:
  fine_tuned_model = PeftModel.from_pretrained(base_model, FINETUNED_MODEL)


print(f"Memory footprint: {fine_tuned_model.get_memory_footprint() / 1e6:.1f} MB")
# Out:
# tokenizer_config.json:   0%|          | 0.00/50.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/73.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/826 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/185 [00:00<?, ?B/s]
# adapter_config.json:   0%|          | 0.00/752 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/109M [00:00<?, ?B/s]
# Memory footprint: 5700.6 MB

# %%
fine_tuned_model
# Out:
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): LlamaForCausalLM(
#       (model): LlamaModel(
#         (embed_tokens): Embedding(128256, 4096)
#         (layers): ModuleList(
#           (0-31): 32 x LlamaDecoderLayer(
#             (self_attn): LlamaAttention(
#               (q_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (k_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (v_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (o_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#             )
#             (mlp): LlamaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (act_fn): SiLU()
#             )
#             (input_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#             (post_attention_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#           )
#         )
#         (norm): LlamaRMSNorm((4096,), eps=1e-05)
#         (rotary_emb): LlamaRotaryEmbedding()
#       )
#       (lm_head): Linear(in_features=4096, out_features=128256, bias=False)
#     )
#   )
# )

# %% [markdown]
# ## Use the model in inference mode
#
#
# ## Caveat
#
# The prices of goods vary considerably; the model can't predict things like sale prices that it doesn't have any information about.

# %%
def extract_price(s):
    if "Price is $" in s:
      contents = s.split("Price is $")[1]
      contents = contents.replace(',','')
      match = re.search(r"[-+]?\d*\.\d+|\d+", contents)
      return float(match.group()) if match else 0
    return 0

# %%
# Original prediction function takes the most likely next token

def model_predict(prompt):
    set_seed(42)
    inputs = tokenizer.encode(prompt, return_tensors="pt").to("cuda")
    attention_mask = torch.ones(inputs.shape, device="cuda")
    outputs = fine_tuned_model.generate(inputs, attention_mask=attention_mask, max_new_tokens=3, num_return_sequences=1)
    response = tokenizer.decode(outputs[0])
    return extract_price(response)

# %%
# An improved prediction function takes a weighted average of the top 3 choices
# We are taking advantage of the fact that Llama generates 1 token for any 3 digit number

top_K = 3

def improved_model_predict(prompt, device="cuda"):
    set_seed(42)
    inputs = tokenizer.encode(prompt, return_tensors="pt").to(device)
    attention_mask = torch.ones(inputs.shape, device=device)

    with torch.no_grad():
        outputs = fine_tuned_model(inputs, attention_mask=attention_mask)
        next_token_logits = outputs.logits[:, -1, :].to('cpu')

    next_token_probs = F.softmax(next_token_logits, dim=-1)
    top_prob, top_token_id = next_token_probs.topk(top_K)
    prices, weights = [], []
    for i in range(top_K):
      predicted_token = tokenizer.decode(top_token_id[0][i])
      probability = top_prob[0][i]
      try:
        result = float(predicted_token)
      except ValueError as e:
        result = 0.0
      if result > 0:
        prices.append(result)
        weights.append(probability)
    if not prices:
      return 0.0, 0.0
    total = sum(weights)
    weighted_prices = [price * weight / total for price, weight in zip(prices, weights)]
    return sum(weighted_prices).item()

# %%
class Tester:

    def __init__(self, predictor, data, title=None, size=250):
        self.predictor = predictor
        self.data = data
        self.title = title or predictor.__name__.replace("_", " ").title()
        self.size = size
        self.guesses = []
        self.truths = []
        self.errors = []
        self.sles = []
        self.colors = []

    def color_for(self, error, truth):
        if error<40 or error/truth < 0.2:
            return "green"
        elif error<80 or error/truth < 0.4:
            return "orange"
        else:
            return "red"

    def run_datapoint(self, i):
        datapoint = self.data[i]
        guess = self.predictor(datapoint["text"])
        truth = datapoint["price"]
        error = abs(guess - truth)
        log_error = math.log(truth+1) - math.log(guess+1)
        sle = log_error ** 2
        color = self.color_for(error, truth)
        title = datapoint["text"].split("\n\n")[1][:20] + "..."
        self.guesses.append(guess)
        self.truths.append(truth)
        self.errors.append(error)
        self.sles.append(sle)
        self.colors.append(color)
        print(f"{COLOR_MAP[color]}{i+1}: Guess: ${guess:,.2f} Truth: ${truth:,.2f} Error: ${error:,.2f} SLE: {sle:,.2f} Item: {title}{RESET}")

    def chart(self, title):
        max_error = max(self.errors)
        plt.figure(figsize=(12, 8))
        max_val = max(max(self.truths), max(self.guesses))
        plt.plot([0, max_val], [0, max_val], color='deepskyblue', lw=2, alpha=0.6)
        plt.scatter(self.truths, self.guesses, s=3, c=self.colors)
        plt.xlabel('Ground Truth')
        plt.ylabel('Model Estimate')
        plt.xlim(0, max_val)
        plt.ylim(0, max_val)
        plt.title(title)
        plt.show()

    def report(self):
        average_error = sum(self.errors) / self.size
        rmsle = math.sqrt(sum(self.sles) / self.size)
        hits = sum(1 for color in self.colors if color=="green")
        title = f"{self.title} Error=${average_error:,.2f} RMSLE={rmsle:,.2f} Hits={hits/self.size*100:.1f}%"
        self.chart(title)

    def run(self):
        self.error = 0
        for i in range(self.size):
            self.run_datapoint(i)
        self.report()

    @classmethod
    def test(cls, function, data):
        cls(function, data).run()

# %%
Tester.test(improved_model_predict, test)
# Out:
# 1: Guess: $307.50 Truth: $374.41 Error: $66.91 SLE: 0.04 Item: OEM AC Compressor w/...
# 2: Guess: $144.75 Truth: $225.11 Error: $80.36 SLE: 0.19 Item: Motorcraft YB3125 Fa...
# 3: Guess: $38.00 Truth: $61.68 Error: $23.68 SLE: 0.23 Item: Dorman Front Washer ...
# 4: Guess: $470.00 Truth: $599.99 Error: $129.99 SLE: 0.06 Item: HP Premium HD Plus T...
# 5: Guess: $10.67 Truth: $16.99 Error: $6.32 SLE: 0.19 Item: Super Switch Pickup ...
# 6: Guess: $10.67 Truth: $31.99 Error: $21.32 SLE: 1.08 Item: Horror Bookmarks, Re...
# 7: Guess: $76.00 Truth: $101.79 Error: $25.79 SLE: 0.08 Item: SK6241 - Stinger 4 G...
# 8: Guess: $312.25 Truth: $289.00 Error: $23.25 SLE: 0.01 Item: Godox ML60Bi LED Lig...
# 9: Guess: $802.00 Truth: $635.86 Error: $166.14 SLE: 0.05 Item: Randall G3 Plus Comb...
# 10: Guess: $93.12 Truth: $65.99 Error: $27.14 SLE: 0.12 Item: HOLDWILL 6 Pack LED ...
# 11: Guess: $261.25 Truth: $254.21 Error: $7.04 SLE: 0.00 Item: Viking Horns 3 Gallo...
# 12: Guess: $377.25 Truth: $412.99 Error: $35.74 SLE: 0.01 Item: CURT 70110 Custom To...
# 13: Guess: $261.50 Truth: $205.50 Error: $56.00 SLE: 0.06 Item: Solar HAMMERED BRONZ...
# 14: Guess: $275.50 Truth: $248.23 Error: $27.27 SLE: 0.01 Item: COSTWAY Electric Tum...
# 15: Guess: $349.50 Truth: $399.00 Error: $49.50 SLE: 0.02 Item: FREE SIGNAL TV Trans...
# 16: Guess: $357.50 Truth: $373.94 Error: $16.44 SLE: 0.00 Item: Bilstein 5100 Monotu...
# 17: Guess: $92.81 Truth: $92.89 Error: $0.08 SLE: 0.00 Item: Sangean K-200 Multi-...
# 18: Guess: $110.06 Truth: $51.99 Error: $58.07 SLE: 0.55 Item: Charles Leonard Magn...
# 19: Guess: $247.75 Truth: $179.00 Error: $68.75 SLE: 0.10 Item: Gigabyte AMD Radeon ...
# 20: Guess: $18.95 Truth: $19.42 Error: $0.47 SLE: 0.00 Item: 3dRose LLC 8 x 8 x 0...
# 21: Guess: $469.75 Truth: $539.95 Error: $70.20 SLE: 0.02 Item: ROKINON 85mm F1.4 Au...
# 22: Guess: $105.00 Truth: $147.67 Error: $42.67 SLE: 0.11 Item: Headlight Assembly C...
# 23: Guess: $26.06 Truth: $24.99 Error: $1.07 SLE: 0.00 Item: ASI NAUTICAL 2.5 Inc...
# 24: Guess: $79.00 Truth: $149.00 Error: $70.00 SLE: 0.40 Item: Behringer TUBE OVERD...
# 25: Guess: $11.05 Truth: $16.99 Error: $5.94 SLE: 0.16 Item: Fun Express Insect F...
# 26: Guess: $10.33 Truth: $7.99 Error: $2.34 SLE: 0.05 Item: WAFJAMF Roller Stamp...
# 27: Guess: $227.50 Truth: $199.99 Error: $27.51 SLE: 0.02 Item: Capulina Tiffany Flo...
# 28: Guess: $252.88 Truth: $251.45 Error: $1.43 SLE: 0.00 Item: Apple Watch Series 6...
# 29: Guess: $168.38 Truth: $231.62 Error: $63.25 SLE: 0.10 Item: ICON 01725 Tandem Ax...
# 30: Guess: $104.88 Truth: $135.00 Error: $30.12 SLE: 0.06 Item: SanDisk 128GB Ultra ...
# 31: Guess: $287.00 Truth: $356.62 Error: $69.62 SLE: 0.05 Item: Velvac - 715427
# 2020...
# 32: Guess: $252.75 Truth: $257.99 Error: $5.24 SLE: 0.00 Item: TCMT Passenger Backr...
# 33: Guess: $22.11 Truth: $27.99 Error: $5.88 SLE: 0.05 Item: Alnicov 63.5MM Brass...
# 34: Guess: $114.00 Truth: $171.20 Error: $57.20 SLE: 0.16 Item: Subaru Forester Outb...
# 35: Guess: $261.00 Truth: $225.00 Error: $36.00 SLE: 0.02 Item: Richmond Auto Uphols...
# 36: Guess: $220.75 Truth: $105.00 Error: $115.75 SLE: 0.54 Item: AP-39 Automotive Pai...
# 37: Guess: $379.25 Truth: $299.99 Error: $79.26 SLE: 0.05 Item: Road Top Wireless Ca...
# 38: Guess: $640.50 Truth: $535.09 Error: $105.41 SLE: 0.03 Item: Gibson Performance E...
# 39: Guess: $20.55 Truth: $12.33 Error: $8.22 SLE: 0.23 Item: Bella Tunno Happy Li...
# 40: Guess: $107.25 Truth: $84.99 Error: $22.26 SLE: 0.05 Item: CANMORE H300 Handhel...
# 41: Guess: $14.36 Truth: $15.99 Error: $1.63 SLE: 0.01 Item: DCPOWER AC Adapter C...
# 42: Guess: $34.22 Truth: $62.44 Error: $28.22 SLE: 0.35 Item: Sharp, Commercial De...
# 43: Guess: $90.12 Truth: $82.99 Error: $7.14 SLE: 0.01 Item: Melissa & Doug Lifel...
# 44: Guess: $402.75 Truth: $599.95 Error: $197.20 SLE: 0.16 Item: Sony SSCS8 2-Way Cen...
# 45: Guess: $231.75 Truth: $194.99 Error: $36.76 SLE: 0.03 Item: ASUS Chromebook CX1,...
# 46: Guess: $353.00 Truth: $344.95 Error: $8.05 SLE: 0.00 Item: FiiO X7 32GB Hi-Res ...
# 47: Guess: $39.81 Truth: $37.99 Error: $1.82 SLE: 0.00 Item: TORRO Leather Case C...
# 48: Guess: $221.50 Truth: $224.35 Error: $2.85 SLE: 0.00 Item: Universal Air Condit...
# 49: Guess: $713.00 Truth: $814.00 Error: $101.00 SLE: 0.02 Item: Street Series Stainl...
# 50: Guess: $384.75 Truth: $439.88 Error: $55.13 SLE: 0.02 Item: Lenovo IdeaPad 3 Lap...
# 51: Guess: $425.25 Truth: $341.43 Error: $83.82 SLE: 0.05 Item: Access Bed Covers To...
# 52: Guess: $54.69 Truth: $46.78 Error: $7.91 SLE: 0.02 Item: G.I. JOE Hasbro 3 3/...
# 53: Guess: $165.75 Truth: $171.44 Error: $5.69 SLE: 0.00 Item: T&S Brass Double Pan...
# 54: Guess: $349.50 Truth: $458.00 Error: $108.50 SLE: 0.07 Item: ZTUOAUMA Fuel Inject...
# 55: Guess: $184.62 Truth: $130.75 Error: $53.88 SLE: 0.12 Item: Hp Prime Graphing Ca...
# 56: Guess: $68.88 Truth: $83.81 Error: $14.94 SLE: 0.04 Item: Lowrance Nmea 2000 2...
# 57: Guess: $261.50 Truth: $386.39 Error: $124.89 SLE: 0.15 Item: Jeep Genuine Accesso...
# 58: Guess: $171.88 Truth: $169.00 Error: $2.88 SLE: 0.00 Item: GODOX CB-06 Hard Car...
# 59: Guess: $12.35 Truth: $17.95 Error: $5.60 SLE: 0.12 Item: Au-Tomotive Gold, IN...
# 60: Guess: $236.75 Truth: $269.00 Error: $32.25 SLE: 0.02 Item: Snailfly Black Roof ...
# 61: Guess: $56.75 Truth: $77.77 Error: $21.02 SLE: 0.10 Item: KING SHA Anti Glare ...
# 62: Guess: $68.00 Truth: $88.99 Error: $20.99 SLE: 0.07 Item: APS Compatible with ...
# 63: Guess: $324.25 Truth: $364.41 Error: $40.16 SLE: 0.01 Item: Wilwood Engineering ...
# 64: Guess: $149.00 Truth: $127.03 Error: $21.97 SLE: 0.03 Item: ACDelco Gold Starter...
# 65: Guess: $660.00 Truth: $778.95 Error: $118.95 SLE: 0.03 Item: UWS Matte Black Heav...
# 66: Guess: $213.25 Truth: $206.66 Error: $6.59 SLE: 0.00 Item: Dell Latitude E5440 ...
# 67: Guess: $40.31 Truth: $35.94 Error: $4.37 SLE: 0.01 Item: (Plug and Play) Spar...
# 68: Guess: $265.50 Truth: $149.00 Error: $116.50 SLE: 0.33 Item: The Ultimate Roadsid...
# 69: Guess: $197.50 Truth: $251.98 Error: $54.48 SLE: 0.06 Item: Brand New 18 x 8.5 R...
# 70: Guess: $253.12 Truth: $160.00 Error: $93.12 SLE: 0.21 Item: Headlight Headlamp L...
# 71: Guess: $30.00 Truth: $39.99 Error: $9.99 SLE: 0.08 Item: Lilo And Stitch Delu...
# 72: Guess: $256.00 Truth: $362.41 Error: $106.41 SLE: 0.12 Item: AC Compressor & A/C ...
# 73: Guess: $383.50 Truth: $344.00 Error: $39.50 SLE: 0.01 Item: House Of Troy Pinnac...
# 74: Guess: $35.19 Truth: $25.09 Error: $10.10 SLE: 0.11 Item: Juno T29 WH Floating...
# 75: Guess: $71.12 Truth: $175.95 Error: $104.82 SLE: 0.81 Item: Sherman GO-PARTS - f...
# 76: Guess: $307.50 Truth: $132.64 Error: $174.86 SLE: 0.70 Item: Roland RPU-3 Electro...
# 77: Guess: $265.50 Truth: $422.99 Error: $157.49 SLE: 0.22 Item: Rockland VMI14 12,00...
# 78: Guess: $146.75 Truth: $146.48 Error: $0.27 SLE: 0.00 Item: Max Advanced Brakes ...
# 79: Guess: $155.50 Truth: $156.83 Error: $1.33 SLE: 0.00 Item: Quality-Built 11030 ...
# 80: Guess: $120.25 Truth: $251.99 Error: $131.74 SLE: 0.54 Item: Lucida LG-510 Studen...
# 81: Guess: $263.50 Truth: $940.33 Error: $676.83 SLE: 1.61 Item: Longacre Aluminum Tu...
# 82: Guess: $51.06 Truth: $52.99 Error: $1.93 SLE: 0.00 Item: Motion Pro Adjustabl...
# 83: Guess: $281.25 Truth: $219.95 Error: $61.30 SLE: 0.06 Item: Glyph Thunderbolt 3 ...
# 84: Guess: $328.25 Truth: $441.03 Error: $112.78 SLE: 0.09 Item: TOYO Open Country MT...
# 85: Guess: $134.62 Truth: $168.98 Error: $34.35 SLE: 0.05 Item: Razer Seiren X USB S...
# 86: Guess: $4.05 Truth: $2.49 Error: $1.56 SLE: 0.14 Item: Happy Birthday to Da...
# 87: Guess: $109.25 Truth: $98.62 Error: $10.63 SLE: 0.01 Item: Little Tikes My Real...
# 88: Guess: $319.00 Truth: $256.95 Error: $62.05 SLE: 0.05 Item: Studio M Peace and H...
# 89: Guess: $23.59 Truth: $30.99 Error: $7.40 SLE: 0.07 Item: MyVolts 12V Power Su...
# 90: Guess: $598.00 Truth: $569.84 Error: $28.16 SLE: 0.00 Item: Dell Latitude 7212 R...
# 91: Guess: $163.00 Truth: $177.99 Error: $14.99 SLE: 0.01 Item: Covermates Contour F...
# 92: Guess: $998.00 Truth: $997.99 Error: $0.01 SLE: 0.00 Item: Westin Black HDX Gri...
# 93: Guess: $264.75 Truth: $219.00 Error: $45.75 SLE: 0.04 Item: Fieldpiece JL2 Job L...
# 94: Guess: $260.50 Truth: $225.55 Error: $34.95 SLE: 0.02 Item: hansgrohe Talis S Mo...
# 95: Guess: $850.00 Truth: $495.95 Error: $354.05 SLE: 0.29 Item: G-Technology G-SPEED...
# 96: Guess: $853.50 Truth: $942.37 Error: $88.87 SLE: 0.01 Item: DreamLine Shower Doo...
# 97: Guess: $2.97 Truth: $1.94 Error: $1.03 SLE: 0.09 Item: Sanctuary Square Bac...
# 98: Guess: $310.50 Truth: $284.34 Error: $26.16 SLE: 0.01 Item: Pelican Protector 17...
# 99: Guess: $152.75 Truth: $171.90 Error: $19.15 SLE: 0.01 Item: Brock Replacement Dr...
# 100: Guess: $152.88 Truth: $144.99 Error: $7.88 SLE: 0.00 Item: Carlinkit Ai Box Min...
# 101: Guess: $332.25 Truth: $470.47 Error: $138.22 SLE: 0.12 Item: StarDot YouTube Live...
# 102: Guess: $65.69 Truth: $66.95 Error: $1.26 SLE: 0.00 Item: Atomic Compatible ME...
# 103: Guess: $92.00 Truth: $117.00 Error: $25.00 SLE: 0.06 Item: Bandai Awakening of ...
# 104: Guess: $259.00 Truth: $172.14 Error: $86.86 SLE: 0.17 Item: Fit System 62135G Pa...
# 105: Guess: $369.50 Truth: $392.74 Error: $23.24 SLE: 0.00 Item: Black Horse Black Al...
# 106: Guess: $19.02 Truth: $16.99 Error: $2.03 SLE: 0.01 Item: Dearsun Twinkle Star...
# 107: Guess: $1.83 Truth: $1.34 Error: $0.49 SLE: 0.04 Item: Pokemon - Gallade Sp...
# 108: Guess: $258.00 Truth: $349.98 Error: $91.98 SLE: 0.09 Item: Ibanez GIO Series Cl...
# 109: Guess: $554.00 Truth: $370.71 Error: $183.29 SLE: 0.16 Item: Set 2 Heavy Duty 12 ...
# 110: Guess: $79.94 Truth: $65.88 Error: $14.06 SLE: 0.04 Item: Hairpin Table Legs 2...
# 111: Guess: $262.25 Truth: $229.99 Error: $32.26 SLE: 0.02 Item: Marada Racing Seat w...
# 112: Guess: $3.05 Truth: $9.14 Error: $6.09 SLE: 0.84 Item: Remington Industries...
# 113: Guess: $370.50 Truth: $199.00 Error: $171.50 SLE: 0.38 Item: Acer Ultrabook, Inte...
# 114: Guess: $261.50 Truth: $109.99 Error: $151.51 SLE: 0.74 Item: ICBEAMER 7 RGB LED H...
# 115: Guess: $401.50 Truth: $570.42 Error: $168.92 SLE: 0.12 Item: R1 Concepts Front Re...
# 116: Guess: $263.50 Truth: $279.99 Error: $16.49 SLE: 0.00 Item: Camplux 2.64 GPM Tan...
# 117: Guess: $34.34 Truth: $30.99 Error: $3.35 SLE: 0.01 Item: KNOKLOCK 10 Pack 3.7...
# 118: Guess: $27.39 Truth: $31.99 Error: $4.60 SLE: 0.02 Item: Valley Enterprises Y...
# 119: Guess: $17.34 Truth: $15.90 Error: $1.44 SLE: 0.01 Item: G9 LED Light 100W re...
# 120: Guess: $80.31 Truth: $45.99 Error: $34.32 SLE: 0.30 Item: ZCHAOZ 4 Lights Anti...
# 121: Guess: $239.25 Truth: $113.52 Error: $125.73 SLE: 0.55 Item: Honeywell Honeywell ...
# 122: Guess: $350.50 Truth: $516.99 Error: $166.49 SLE: 0.15 Item: Patriot Exhaust 1-7/...
# 123: Guess: $106.25 Truth: $196.99 Error: $90.74 SLE: 0.38 Item: Fitrite Autopart New...
# 124: Guess: $30.81 Truth: $46.55 Error: $15.74 SLE: 0.16 Item: Technical Precision ...
# 125: Guess: $350.50 Truth: $356.99 Error: $6.49 SLE: 0.00 Item: Covercraft Carhartt ...
# 126: Guess: $284.75 Truth: $319.95 Error: $35.20 SLE: 0.01 Item: Sennheiser SD Pro 2 ...
# 127: Guess: $124.50 Truth: $96.06 Error: $28.44 SLE: 0.07 Item: Hitachi Mass Air Flo...
# 128: Guess: $253.25 Truth: $190.99 Error: $62.26 SLE: 0.08 Item: AmScope LED Cordless...
# 129: Guess: $75.19 Truth: $257.95 Error: $182.76 SLE: 1.50 Item: Front Left Driver Si...
# 130: Guess: $64.69 Truth: $62.95 Error: $1.74 SLE: 0.00 Item: Premium Replica Hubc...
# 131: Guess: $62.97 Truth: $47.66 Error: $15.31 SLE: 0.07 Item: Excellerations Phoni...
# 132: Guess: $145.12 Truth: $226.99 Error: $81.87 SLE: 0.20 Item: RC4WD BigDog Dual Ax...
# 133: Guess: $263.25 Truth: $359.95 Error: $96.70 SLE: 0.10 Item: Unknown Stage 2 Clut...
# 134: Guess: $60.84 Truth: $78.40 Error: $17.56 SLE: 0.06 Item: Dodge Ram 1500 Mopar...
# 135: Guess: $166.00 Truth: $172.77 Error: $6.77 SLE: 0.00 Item: Pro Comp Alloys Seri...
# 136: Guess: $305.25 Truth: $316.45 Error: $11.20 SLE: 0.00 Item: Detroit Axle - Front...
# 137: Guess: $74.75 Truth: $87.99 Error: $13.24 SLE: 0.03 Item: ECCPP Rear Wheel Axl...
# 138: Guess: $257.50 Truth: $226.63 Error: $30.87 SLE: 0.02 Item: Dell Latitude E6520 ...
# 139: Guess: $22.53 Truth: $31.49 Error: $8.96 SLE: 0.10 Item: F FIERCE CYCLE 251pc...
# 140: Guess: $252.50 Truth: $196.00 Error: $56.50 SLE: 0.06 Item: Flash Furniture 4 Pk...
# 141: Guess: $61.06 Truth: $78.40 Error: $17.34 SLE: 0.06 Item: B&M 30287 Throttle V...
# 142: Guess: $141.25 Truth: $116.25 Error: $25.00 SLE: 0.04 Item: Gates TCK226 PowerGr...
# 143: Guess: $131.75 Truth: $112.78 Error: $18.97 SLE: 0.02 Item: Monroe Shocks & Stru...
# 144: Guess: $66.25 Truth: $27.32 Error: $38.93 SLE: 0.75 Item: Feit Electric 35W EQ...
# 145: Guess: $115.69 Truth: $145.91 Error: $30.22 SLE: 0.05 Item: Yellow Jacket 2806 C...
# 146: Guess: $146.88 Truth: $171.09 Error: $24.22 SLE: 0.02 Item: Garage-Pro Tailgate ...
# 147: Guess: $128.88 Truth: $167.95 Error: $39.07 SLE: 0.07 Item: 3M Perfect It Buffin...
# 148: Guess: $34.03 Truth: $28.49 Error: $5.54 SLE: 0.03 Item: Chinese Style Dollho...
# 149: Guess: $61.22 Truth: $122.23 Error: $61.01 SLE: 0.47 Item: Generic NRG Innovati...
# 150: Guess: $30.17 Truth: $32.99 Error: $2.82 SLE: 0.01 Item: Learning Resources C...
# 151: Guess: $84.12 Truth: $71.20 Error: $12.92 SLE: 0.03 Item: Bosch Automotive 154...
# 152: Guess: $44.75 Truth: $112.75 Error: $68.00 SLE: 0.83 Item: Case of 24-2 Inch Bl...
# 153: Guess: $105.38 Truth: $142.43 Error: $37.06 SLE: 0.09 Item: MOCA Engine Water Pu...
# 154: Guess: $265.50 Truth: $398.99 Error: $133.49 SLE: 0.16 Item: SAREMAS Foot Step Ba...
# 155: Guess: $501.50 Truth: $449.00 Error: $52.50 SLE: 0.01 Item: Gretsch G9210 Square...
# 156: Guess: $154.88 Truth: $189.00 Error: $34.12 SLE: 0.04 Item: NikoMaku Mirror Dash...
# 157: Guess: $146.50 Truth: $120.91 Error: $25.59 SLE: 0.04 Item: Fenix HP25R v2.0 USB...
# 158: Guess: $180.75 Truth: $203.53 Error: $22.78 SLE: 0.01 Item: R&L Racing Heavy Dut...
# 159: Guess: $352.00 Truth: $349.99 Error: $2.01 SLE: 0.00 Item: Garmin GPSMAP 64sx, ...
# 160: Guess: $9.34 Truth: $34.35 Error: $25.01 SLE: 1.51 Item: Brown 5-7/8 X 8-1/2 ...
# 161: Guess: $376.00 Truth: $384.99 Error: $8.99 SLE: 0.00 Item: GAOMON PD2200 Pen Di...
# 162: Guess: $189.50 Truth: $211.00 Error: $21.50 SLE: 0.01 Item: VXMOTOR for 97-03 Fo...
# 163: Guess: $237.50 Truth: $129.00 Error: $108.50 SLE: 0.37 Item: HP EliteBook 2540p I...
# 164: Guess: $26.06 Truth: $111.45 Error: $85.39 SLE: 2.03 Item: Green EPX Mixing Noz...
# 165: Guess: $25.50 Truth: $81.12 Error: $55.62 SLE: 1.28 Item: Box Partners 6 1/4 x...
# 166: Guess: $354.50 Truth: $457.08 Error: $102.58 SLE: 0.06 Item: Vixen Air 1/2 NPT Ai...
# 167: Guess: $80.19 Truth: $49.49 Error: $30.70 SLE: 0.23 Item: Smart Floor Lamp, Mu...
# 168: Guess: $67.25 Truth: $80.56 Error: $13.31 SLE: 0.03 Item: SOZG 324mm Wheelbase...
# 169: Guess: $311.50 Truth: $278.39 Error: $33.11 SLE: 0.01 Item: Mickey Thompson ET S...
# 170: Guess: $340.75 Truth: $364.50 Error: $23.75 SLE: 0.00 Item: Pirelli 106W XL RFT ...
# 171: Guess: $383.50 Truth: $378.99 Error: $4.51 SLE: 0.00 Item: Torklift C3212 Rear ...
# 172: Guess: $178.38 Truth: $165.28 Error: $13.09 SLE: 0.01 Item: Cardone Remanufactur...
# 173: Guess: $45.31 Truth: $56.74 Error: $11.43 SLE: 0.05 Item: Kidde AccessPoint 00...
# 174: Guess: $262.50 Truth: $307.95 Error: $45.45 SLE: 0.03 Item: 3M Protecta Self Ret...
# 175: Guess: $58.69 Truth: $38.00 Error: $20.69 SLE: 0.18 Item: Plantronics Wired He...
# 176: Guess: $257.25 Truth: $53.00 Error: $204.25 SLE: 2.45 Item: Logitech K750 Wirele...
# 177: Guess: $546.00 Truth: $498.00 Error: $48.00 SLE: 0.01 Item: Olympus PEN E-PL9 Bo...
# 178: Guess: $131.75 Truth: $53.99 Error: $77.76 SLE: 0.78 Item: Beck/Arnley Hub & Be...
# 179: Guess: $349.00 Truth: $350.00 Error: $1.00 SLE: 0.00 Item: Eibach Pro-Kit Perfo...
# 180: Guess: $267.00 Truth: $299.95 Error: $32.95 SLE: 0.01 Item: LEGO DC Batman 1989 ...
# 181: Guess: $103.06 Truth: $94.93 Error: $8.13 SLE: 0.01 Item: Kingston Brass Resto...
# 182: Guess: $314.50 Truth: $379.00 Error: $64.50 SLE: 0.03 Item: Polk Vanishing Serie...
# 183: Guess: $261.50 Truth: $299.95 Error: $38.45 SLE: 0.02 Item: Spec-D Tuning LED Pr...
# 184: Guess: $12.42 Truth: $24.99 Error: $12.57 SLE: 0.44 Item: RICHMOND & FINCH Air...
# 185: Guess: $85.31 Truth: $41.04 Error: $44.27 SLE: 0.52 Item: LFA Industries - mm ...
# 186: Guess: $262.00 Truth: $327.90 Error: $65.90 SLE: 0.05 Item: SAUTVS LED Headlight...
# 187: Guess: $19.03 Truth: $10.99 Error: $8.04 SLE: 0.26 Item: 2 Pack Combo Womens ...
# 188: Guess: $14.98 Truth: $14.99 Error: $0.01 SLE: 0.00 Item: Arepa - Venezuelan c...
# 189: Guess: $24.48 Truth: $84.95 Error: $60.47 SLE: 1.48 Item: Schlage Lock Company...
# 190: Guess: $92.12 Truth: $111.00 Error: $18.88 SLE: 0.03 Item: Techni Mobili White ...
# 191: Guess: $187.38 Truth: $123.73 Error: $63.64 SLE: 0.17 Item: Special Lite Product...
# 192: Guess: $361.25 Truth: $557.38 Error: $196.13 SLE: 0.19 Item: Tascam Digital Porta...
# 193: Guess: $75.62 Truth: $95.55 Error: $19.92 SLE: 0.05 Item: Glow Lighting Vista ...
# 194: Guess: $248.50 Truth: $154.00 Error: $94.50 SLE: 0.23 Item: Z3 Wind Deflector, S...
# 195: Guess: $242.75 Truth: $198.99 Error: $43.76 SLE: 0.04 Item: Olympus E-20 5MP Dig...
# 196: Guess: $264.00 Truth: $430.44 Error: $166.44 SLE: 0.24 Item: PHYNEDI 1 1000 World...
# 197: Guess: $19.00 Truth: $45.67 Error: $26.67 SLE: 0.72 Item: YANGHUAN Unstable Un...
# 198: Guess: $312.00 Truth: $249.00 Error: $63.00 SLE: 0.05 Item: Interlogix NetworX T...
# 199: Guess: $9.39 Truth: $42.99 Error: $33.60 SLE: 2.08 Item: Steering Damper,Univ...
# 200: Guess: $110.56 Truth: $181.33 Error: $70.77 SLE: 0.24 Item: Amprobe TIC 410A Hot...
# 201: Guess: $3.02 Truth: $6.03 Error: $3.01 SLE: 0.31 Item: MyCableMart 3.5mm Pl...
# 202: Guess: $45.38 Truth: $29.99 Error: $15.39 SLE: 0.16 Item: OtterBox + Pop Symme...
# 203: Guess: $784.50 Truth: $899.00 Error: $114.50 SLE: 0.02 Item: Dell XPS Desktop ( I...
# 204: Guess: $599.00 Truth: $399.99 Error: $199.01 SLE: 0.16 Item: Franklin Iron Works ...
# 205: Guess: $4.28 Truth: $4.66 Error: $0.38 SLE: 0.00 Item: Avery Legal Dividers...
# 206: Guess: $142.50 Truth: $261.41 Error: $118.91 SLE: 0.36 Item: Moen 8346 Commercial...
# 207: Guess: $144.88 Truth: $136.97 Error: $7.91 SLE: 0.00 Item: Carlisle Versa Trail...
# 208: Guess: $139.25 Truth: $79.00 Error: $60.25 SLE: 0.32 Item: SUNWAYFOTO 44mm Trip...
# 209: Guess: $317.25 Truth: $444.99 Error: $127.74 SLE: 0.11 Item: NanoBeam AC 4 Units ...
# 210: Guess: $519.50 Truth: $411.94 Error: $107.56 SLE: 0.05 Item: WULF 4 Front 2 Rear ...
# 211: Guess: $162.62 Truth: $148.40 Error: $14.22 SLE: 0.01 Item: Alera ALEVABFMC Vale...
# 212: Guess: $84.31 Truth: $244.99 Error: $160.68 SLE: 1.12 Item: YU-GI-OH! Ignition A...
# 213: Guess: $264.75 Truth: $86.50 Error: $178.25 SLE: 1.23 Item: 48 x 36 Extra-Large ...
# 214: Guess: $131.38 Truth: $297.95 Error: $166.57 SLE: 0.66 Item: Dell Latitude D620 R...
# 215: Guess: $450.50 Truth: $399.99 Error: $50.51 SLE: 0.01 Item: acer Aspire 5 Laptop...
# 216: Guess: $318.75 Truth: $599.00 Error: $280.25 SLE: 0.40 Item: Elk 30 by 6-Inch Viv...
# 217: Guess: $221.00 Truth: $105.99 Error: $115.01 SLE: 0.53 Item: Barbie Top Model Dol...
# 218: Guess: $597.00 Truth: $689.00 Error: $92.00 SLE: 0.02 Item: Danby Designer 20-In...
# 219: Guess: $415.00 Truth: $404.99 Error: $10.01 SLE: 0.00 Item: FixtureDisplays® Met...
# 220: Guess: $196.38 Truth: $207.76 Error: $11.38 SLE: 0.00 Item: ACDelco GM Original ...
# 221: Guess: $200.25 Truth: $171.82 Error: $28.43 SLE: 0.02 Item: EBC Premium Street B...
# 222: Guess: $311.00 Truth: $293.24 Error: $17.76 SLE: 0.00 Item: FXR Men's Boost FX J...
# 223: Guess: $350.00 Truth: $374.95 Error: $24.95 SLE: 0.00 Item: SuperATV Scratch Res...
# 224: Guess: $93.81 Truth: $111.99 Error: $18.18 SLE: 0.03 Item: SBU 3 Layer All Weat...
# 225: Guess: $35.38 Truth: $42.99 Error: $7.62 SLE: 0.04 Item: 2 Pack Outdoor Broch...
# 226: Guess: $131.75 Truth: $116.71 Error: $15.04 SLE: 0.01 Item: Monroe Shocks & Stru...
# 227: Guess: $191.50 Truth: $118.61 Error: $72.89 SLE: 0.23 Item: Elements of Design M...
# 228: Guess: $140.62 Truth: $147.12 Error: $6.50 SLE: 0.00 Item: GM Genuine Parts Air...
# 229: Guess: $241.50 Truth: $119.99 Error: $121.51 SLE: 0.48 Item: Baseus USB C Docking...
# 230: Guess: $366.00 Truth: $369.98 Error: $3.98 SLE: 0.00 Item: Whitehall™ Personali...
# 231: Guess: $276.00 Truth: $315.55 Error: $39.55 SLE: 0.02 Item: Pro Circuit Works Pi...
# 232: Guess: $279.75 Truth: $190.99 Error: $88.76 SLE: 0.14 Item: HYANKA 15 1200W Prof...
# 233: Guess: $215.25 Truth: $155.00 Error: $60.25 SLE: 0.11 Item: Bluetooth X6BT Card ...
# 234: Guess: $333.00 Truth: $349.99 Error: $16.99 SLE: 0.00 Item: AIRAID Cold Air Inta...
# 235: Guess: $261.25 Truth: $249.99 Error: $11.26 SLE: 0.00 Item: Bostingner Shower Fa...
# 236: Guess: $26.98 Truth: $42.99 Error: $16.01 SLE: 0.20 Item: PIT66 Front Bumper T...
# 237: Guess: $13.66 Truth: $17.99 Error: $4.33 SLE: 0.07 Item: Caseology Bumpy Comp...
# 238: Guess: $349.00 Truth: $425.00 Error: $76.00 SLE: 0.04 Item: Fleck 2510 Timer Mec...
# 239: Guess: $190.88 Truth: $249.99 Error: $59.12 SLE: 0.07 Item: Haloview MC7108 Wire...
# 240: Guess: $45.72 Truth: $138.23 Error: $92.51 SLE: 1.19 Item: Schmidt Spiele - Man...
# 241: Guess: $313.50 Truth: $414.99 Error: $101.49 SLE: 0.08 Item: Corsa 14333 Tip Kit ...
# 242: Guess: $157.00 Truth: $168.28 Error: $11.28 SLE: 0.00 Item: Hoshizaki FM116A Fan...
# 243: Guess: $265.75 Truth: $199.99 Error: $65.76 SLE: 0.08 Item: BAINUO Antler Chande...
# 244: Guess: $128.75 Truth: $126.70 Error: $2.05 SLE: 0.00 Item: DNA MOTORING Smoke L...
# 245: Guess: $3.91 Truth: $5.91 Error: $2.00 SLE: 0.12 Item: Wera Stainless 3840/...
# 246: Guess: $299.50 Truth: $193.06 Error: $106.44 SLE: 0.19 Item: Celestron - PowerSee...
# 247: Guess: $249.50 Truth: $249.99 Error: $0.49 SLE: 0.00 Item: NHOPEEW Android Car ...
# 248: Guess: $82.00 Truth: $64.12 Error: $17.88 SLE: 0.06 Item: Other Harmonica A)
# F...
# 249: Guess: $249.25 Truth: $114.99 Error: $134.26 SLE: 0.59 Item: Harley Air Filter Ve...
# 250: Guess: $399.00 Truth: $926.00 Error: $527.00 SLE: 0.71 Item: Elite Screens Edge F...
